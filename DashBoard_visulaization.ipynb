# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install dash
# Out:
# Requirement already satisfied: numpy in c:\users\91887\anaconda3\lib\site-packages (1.21.5)
# Requirement already satisfied: pandas in c:\users\91887\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91887\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\91887\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\91887\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\91887\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\91887\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\91887\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\91887\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\91887\anaconda3\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\91887\anaconda3\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\91887\anaconda3\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: numpy>=1.15 in c:\users\91887\anaconda3\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\91887\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91887\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\91887\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: dash in c:\users\91887\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\91887\anaconda3\lib\site-packages (from dash) (5.9.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\91887\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\91887\anaconda3\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\91887\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\91887\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\91887\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\91887\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\91887\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\91887\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\91887\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (4.11.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\91887\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: colorama in c:\users\91887\anaconda3\lib\site-packages (from click>=8.0->Flask>=1.0.4->dash) (0.4.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\91887\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0->Flask>=1.0.4->dash) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\91887\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash) (2.1.2)

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

# Load FIFA - World CUP dataset
df = pd.read_csv('FIFA - World Cup.csv')

# Create the app
app = dash.Dash(__name__)

# Define the layout
app.layout = html.Div([
    html.H1('FIFA - World Cup Dashboard'),

    # Scatter plot
    dcc.Graph(id='scatterplot',
              figure={
                  'data': [
                      go.Scatter(x=df['CHAMPION'],
                                 y=df['          YEAR'],
                                 mode='markers')
                  ],
                  'layout': {
                      'title': 'Scatter plot',
                      'xaxis': {'title': 'CHAMPION'},
                      'yaxis': {'title': '          YEAR'}
                  }
              }),

    # Box plot
    dcc.Graph(id='boxplot',
              figure={
                  'data': [
                      go.Box(y=df['TEAMS'], name='TEAMS'),
                      go.Box(y=df['MATCHES PLAYED'], name='MATCHES PLAYED')
                  ],
                  'layout': {
                      'title': 'Box plot',
                      'yaxis': {'title': 'Number of Teams/Matches Played'}
                  }
              }),

    # Histogram
    dcc.Graph(id='histogram',
              figure={
                  'data': [
                      go.Histogram(x=df['RUNNER UP'], nbinsx=10)
                  ],
                  'layout': {
                      'title': 'Histogram ',
                      'xaxis': {'title': 'Runner Up'}
                  }
              }),

    # Mosaic plot
    dcc.Graph(id='mosaicplot',
              figure={
                  'data': [
                      go.Heatmap(x=df['HOST'],
                                 y=df['THIRD PLACE'],
                                 z=df['GOALS SCORED'],
                                 colorscale='GnBu')
                  ],
                  'layout': {
                      'title': 'Mosaic plot',
                      'xaxis': {'title': 'HOST'},
                      'yaxis': {'title': 'THIRD PLACE'}
                  }
              }),

    # Bar chart
    dcc.Graph(id='barchart',
              figure=px.bar(df, x='CHAMPION', y='HOST', color='          YEAR',
                            title='Bar chart',
                            labels={'CHAMPION': 'CHAMPION Of THE MATCH', 'HOST': 'HOST',
                                    'Season': 'Season'})
              )
])

if __name__ == '__main__':
    app.run_server(port=8000)
# Out:
# Dash is running on http://127.0.0.1:8000/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8000
# Press CTRL+C to quit
# 127.0.0.1 - - [25/Mar/2023 17:50:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2023 17:50:34] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2023 17:50:34] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2023 17:50:34] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [25/Mar/2023 17:50:34] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
